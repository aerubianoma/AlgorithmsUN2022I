# %% [markdown]
# https://algorithmsun.wordpress.com/15-pancakes-with-a-problem/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pydotplus
from collections import defaultdict 
from IPython.display import Image, display
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])

# %%
def ModifiedBFS(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydotplus.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydotplus.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                q += 1
                if (d != s) and not(lstr(d) in visited.keys()):
                  if(d != sorted(d)):
                    node = pydotplus.Node(lstr(d))
                  else:

                    node = pydotplus.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  G.add_node(node)
                  edge = pydotplus.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)
        return graph

# %%
p = [1,3,2,4]
result = ModifiedBFS(p)

# %%
def ModifiedBFS(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydotplus.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
        p_n = 0
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydotplus.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
                p_n+=1
                for i in range(len(s)-1):
                    d = s[i+1::-1] + s[i+2:]  
                    if (d != s) and not(lstr(d) in visited.keys()):
                        if(d != sorted(d)):
                            node = pydotplus.Node(lstr(d))
                        else:
                            final= p_n
                            node = pydotplus.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                        G.add_node(node)
                        edge = pydotplus.Edge(lstr(s),lstr(d))
                        G.add_edge(edge)
                        graph[lstr(s)].append(lstr(d))
                        queue.append(d) 
                        visited[lstr(d)] = True 
            
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)
        return final

# %%
p = [1,4,2,3]
ModifiedBFS(p)
i = 0
while True:
    if 
    i += 1
# Out:
# 6

# %%
def ModifiedBFSPreSols(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydotplus.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydotplus.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydotplus.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydotplus.Node(lstr(d))
                  else:
                    node = pydotplus.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydotplus.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [1,3,2]
ModifiedBFSPreSols(p)

# %%
def ModifiedBFSPreSolsLevel(s,L):  

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)) and (l < L):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append([d,l+1]) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [5,2,3,4,1]
ModifiedBFSPreSolsLevel(p,3)

# %%
ModifiedBFSPreSolsLevel(p,5)

# %%
p = [2,3,4,1]
ModifiedBFSPreSolsLevel(p,5)

# %% [markdown]
# ## References
#
# - Breadth First Search or BFS for a Graph https://www.geeksforgeeks.org/breadth-first-search-or-bfs-for-a-graph/
#
# - Graph visualization using Python https://www.youtube.com/watch?v=SpDI6-FvtJY
#
# - nikhilkumarsingh
# /
# PyDot-Examples https://github.com/nikhilkumarsingh/PyDot-Examples/blob/master/Directory_Structure_Plotter.ipynb
#
# - pydot https://pypi.org/project/pydot/
#
# - Graphviz https://www.graphviz.org/
#
# - NetworkX https://networkx.github.io/

# %% [markdown]
# # MY SOLUTION:

# %% [markdown]
# 1. Modify the PancakesTrees.ipynb code in your own to plot the Pancake Network and calculate Pn for smal n‘s.

# %%
def ModifiedBFS(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydotplus.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
        lev = dict()
        lev[lstr(s)]=0
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydotplus.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                  lev[lstr(d)]=1 +lev[lstr(s)]
                  if(d != sorted(d)):
                    node = pydotplus.Node(lstr(d))
                  else:

                    node = pydotplus.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  G.add_node(node)
                  edge = pydotplus.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        Pn=lev[lstr(s)]
        im = Image(G.create_png())
        display(im)
        return Pn
p = [1,3,2]
result = ModifiedBFS(p)
print('In this case Pn is: ' +str(result))
# Out:
# In this case Pn is: 3

# %% [markdown]
# 2. Modify the PancakesTrees.ipynb code leaving only the necessary code and data structures required to calculate the Pn and run the code for at least one night (8 hours) starting with n=5. What is the largest Pn calculated? (Save the results in drive to avoid losing them)

# %%
def ModifiedBFSPreSols(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
              
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
        lev = dict()
        lev[lstr(s)]=0
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            for i in range(len(s)-1):
              d = s[i+1::-1] + s[i+2:]  
              if (d != s) and not(lstr(d) in visited.keys()):
                lev[lstr(d)]=1 +lev[lstr(s)]

                edge = pydotplus.Edge(lstr(s),lstr(d))
                graph[lstr(s)].append(lstr(d))
                queue.append(d) 
                visited[lstr(d)] = True 
        Pn=lev[lstr(s)]
        return Pn

# %%
import random
from time import time
with open('results.txt', 'w') as f:
    it = time()
    f.write('Here are the results of 8 hours: \n')
    k = 5
    while True:
        randomlist = random.sample(range(1, k+1), k)
        f.write('for k = '+str(k)+' Pn is : '+str(ModifiedBFSPreSols(randomlist))+'\n')
        k += 1
        if time()-it>28800:
             break
    f.write('Total time: '+str(time()-it)+'\n')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.625002 to fit
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.0818259 to fit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-193-cf0827283d26> in <module>
#       7     while True:
#       8         randomlist = random.sample(range(1, k+1), k)
# ----> 9         f.write('for k = '+str(k)+' Pn is : '+str(ModifiedBFSPreSols(randomlist))+'\n')
#      10         k += 1
#      11         if time()-it>28800:
#
# <ipython-input-191-40f1d89a9acf> in ModifiedBFSPreSols(s)
#      51
#      52                         G.add_node(node)
# ---> 53                         edge = pydotplus.Edge(lstr(s),lstr(d))
#      54                         G.add_edge(edge)
#      55                         graph[lstr(s)].append(lstr(d))
#
# ~\anaconda3\lib\site-packages\pydotplus\graphviz.py in __init__(self, src, dst, obj_dict, **attrs)
#     952             self.obj_dict['points'] = points
#     953
# --> 954         self.create_attribute_methods(EDGE_ATTRIBUTES)
#     955
#     956     def get_source(self):
#
# ~\anaconda3\lib\site-packages\pydotplus\graphviz.py in create_attribute_methods(self, obj_attributes)
#     759             # Generate all the Getter methods.
#     760             #
# --> 761             self.__setattr__(
#     762                 'get_' + attr,
#     763                 lambda a=attr: self.__get_attribute__(a)
#
# KeyboardInterrupt:

# %% [markdown]
# 3. Modify the PancakesTrees.ipynb code to plot the pancakes trees using two spatulas.

# %%
def ModifiedBFSPreSols2(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydotplus.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydotplus.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydotplus.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
                  for i in range(len(s) - 1):
                    for j in range(i + 1, len(s)):
                      if i != 0:
                        d = s[:i] + s[j:i - 1:-1] + s[j + 1:]
                      else:
                        d = s[j::-1] + s[j + 1:]

                      if (d != s) and not(lstr(d) in visited.keys()):
                      
                        if(d != sorted(d)):
                          node = pydotplus.Node(lstr(d))
                        else:
                          node = pydotplus.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                        
                        G.add_node(node)
                        edge = pydotplus.Edge(lstr(s),lstr(d))
                        G.add_edge(edge)
                        graph[lstr(s)].append(lstr(d))
                        queue.append(d) 
                        visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [4,2,1,3]
ModifiedBFSPreSols2(p)
