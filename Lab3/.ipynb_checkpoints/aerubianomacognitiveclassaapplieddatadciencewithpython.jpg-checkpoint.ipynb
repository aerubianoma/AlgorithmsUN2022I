# %% [markdown]
# # Data Analysis Certification
#
# My linkedin profile is available in: https://www.linkedin.com/in/aerubianoma/

# %% [markdown]
# # 1. Python for data science
#
# ![python-for-data-science.png](attachment:python-for-data-science.png)

# %%
from IPython.display import IFrame
IFrame("./Python_for_Data_Science_Badge20220404-46-1q21ud4.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="./Python_for_Data_Science_Badge20220404-46-1q21ud4.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 2. Data analysis using python
#
# ![data-analysis-using-python.png](attachment:data-analysis-using-python.png)

# %%
from IPython.display import IFrame
IFrame("./Data_Analysis_Using_Python_Badge20220404-46-zorch4.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="./Data_Analysis_Using_Python_Badge20220404-46-zorch4.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 3. Data visualization using python
#
# ![data-visualization-using-python.png](attachment:data-visualization-using-python.png)

# %%
from IPython.display import IFrame
IFrame("./Data_Visualization_Using_Python_Badge20220404-46-1kb002w.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="./Data_Visualization_Using_Python_Badge20220404-46-1kb002w.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Linkedin screencshot
#
# Here is the Linkedin screenshot:
#
# ![Screenshot%202022-04-04%20150916.png](attachment:Screenshot%202022-04-04%20150916.png)
